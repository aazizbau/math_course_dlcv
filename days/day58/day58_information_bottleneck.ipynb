# %% [markdown]
# # Day 58 — "Information Bottleneck & Representation Learning: Why Networks Compress Data"
#
# Information bottleneck views learning as compressing inputs while preserving task-relevant information.

# %%
# Ensure repo root is on sys.path for local imports
import sys
from pathlib import Path

repo_root = Path.cwd()
if not (repo_root / "days").exists():
    for parent in Path.cwd().resolve().parents:
        if (parent / "days").exists():
            repo_root = parent
            break

sys.path.insert(0, str(repo_root))
print(f"Using repo root: {repo_root}")
# Out:
# Using repo root: /media/abdul-aziz/sdb7/masters_research/math_course_dlcv

# %% [markdown]
# ## 1. The Information Bottleneck Objective
# We trade off compression \(I(T;X)\) with prediction \(I(T;Y)\).

# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.random.randn(500, 2)
Y = (X[:,0] + X[:,1] > 0).astype(int)
T = X @ np.array([[1.0],[1.0]])

plt.subplot(1,2,1)
plt.scatter(X[:,0], X[:,1], c=Y, alpha=0.5)
plt.title('Input Space')

plt.subplot(1,2,2)
plt.scatter(T, np.zeros_like(T), c=Y, alpha=0.5)
plt.title('Compressed Representation')
plt.show()

# %% [markdown]
# ## 2. Reusable Module
# ```bash
# python -m days.day58.code.information_bottleneck_demo
# ```

# %% [markdown]
# ## 3. Visualization
# Run the visualization script to generate plots in `days/day58/outputs/`.

# %%
# from days.day58.code.visualizations import main
# main()

# %% [markdown]
# ## 4. Key Takeaways
# - Good representations compress inputs while preserving label information.
# - Mutual information formalizes the tradeoff.
# - Noise and depth encourage compression.
